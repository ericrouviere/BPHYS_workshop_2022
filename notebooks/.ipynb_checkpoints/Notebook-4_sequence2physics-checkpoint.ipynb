# %% [markdown]
# # Notebook 4: Giving the elastic network a sequence.
#
# In the last notebook (1) we defined a structure $r$ and an Adjacency matrix $A$. If we are going to somehow evolve this model of a protein, it better have a sequence. Lets give it one.
#
# Let's define a sequence $s = (s_1,...,s_N)$ where $N = W  L$ is the sequence's length. We can think of each element of $s$ to be label of one of $q$ node types i.e. $s_i \in [1, \dots, q]$.
#
# For example we have a network with width $W = 5$ and length $L=5$, and we define the number of node types to be $q=5$ then one possible sequence could be,
#
# $s = (1, 1, 4, 2, 1, 2, 2, 2, 5, 2, 5, 3, 3, 5, 4, 2, 1, 2, 2, 1, 5, 3, 3, 1, 4)$

# %%
# Load code
using PyPlot, LaTeXStrings, LinearAlgebra, Revise
push!(LOAD_PATH, "../src/")
using Elastic_N3
# Out:
# ┌ Info: Precompiling Elastic_N3 [top-level]
# └ @ Base loading.jl:1664

# %%
W, L, q = 5, 5, 5
seq = rand(1:q, W*L)
@show seq;
# Out:
# seq = [2, 3, 2, 1, 2, 5, 1, 3, 2, 4, 2, 1, 4, 3, 5, 4, 1, 2, 2, 2, 1, 5, 3, 3, 2]

# %% [markdown]
# Now that we have a sequence how does it define a particular network? One way is to make the stiffness of the springs depend on the sequence. Let $S_{ij}$ be a matrix whose entries equal the stiffness between node $i$ and node $j$. $S_{ij}=0$ if nodes $i,j$  aren't connected by a spring. Further, let $K(s_i,s_j)$ be an interaction table that defines the spring stiffness between a node of type $s_i$ and a node of type $s_j$.
#
# The full "genotype to phenotype" map is,
#
# $$ S_{ij} = A_{ij} K(s_i,s_j) $$
#
#
# How should we chose the entries of $K$? We want some of the interactions to be stiff while others are soft. One option is to pull values from a Log Uniform distribution.

# %% [markdown]
# ## **YOU TRY**: Make a function called `buildSpringTable` that takes the arugments, `q`, `k_min`, `k_max` and returns a $q$ x $q$ symmetric matrix with entries log uniformly distributed in [`k_min`, `k_max`]$

# %%
# build spring constant interaction table
# function buildSpringTable(q, k_min, k_max)
    
#     K = 10 .^ (log(10,k_max) - log(10,k_min)) .* rand(q,q)
    
#     return K
# end

function buildSpringTable(q, k_min, k_max)
    log_diff = log(10, k_max) - log(10, k_min)
    K =  10 .^ (rand(q, q) .* log_diff .+ log(10,k_min))
    K = Float64.(Symmetric(K, :L))
    return K
end
# Out:
# buildSpringTable (generic function with 1 method)

# %%
q, k_min, k_max = 20, 1e-2, 1e1
K = buildSpringTable(q, k_min, k_max)
# Out:
# 20×20 Matrix{Float64}:
#  0.361525   0.119821   1.31743    …  0.0269426  0.0692593  2.34352
#  0.119821   0.34869    0.0131423     0.0536163  0.331586   0.0131166
#  1.31743    0.0131423  0.339975      0.13263    0.611047   0.0839613
#  0.221407   0.0151119  0.153331      0.260906   0.278692   0.0126034
#  0.0153799  3.15837    0.015262      0.0295753  9.1479     3.02776
#  0.0239528  1.48991    1.28501    …  0.30295    0.366132   1.88407
#  0.0301327  0.0170987  0.186899      0.136476   0.351368   0.060435
#  2.68288    5.08352    0.0212848     0.0368955  1.94415    0.024675
#  6.48228    0.124595   6.24626       0.233094   1.07934    0.0904058
#  0.391776   2.96281    0.181437      2.21275    2.10424    0.0654838
#  8.29693    0.0132381  4.19221    …  4.56721    0.113125   8.45835
#  0.0146244  0.972835   0.394262      0.582883   0.289536   0.0552632
#  7.80399    0.0248965  0.0508958     0.0227648  0.0158107  0.904227
#  4.1664     6.58541    0.282941      1.03337    0.0211872  0.0135233
#  0.100457   0.0253784  1.57336       0.110691   2.46183    6.41121
#  0.057456   0.0912505  0.990227   …  6.36631    1.14133    0.568622
#  0.295546   1.97864    0.159488      2.81863    1.29155    0.764938
#  0.0269426  0.0536163  0.13263       0.0733081  0.0500037  0.362672
#  0.0692593  0.331586   0.611047      0.0500037  0.0453604  0.0123293
#  2.34352    0.0131166  0.0839613     0.362672   0.0123293  5.93587

# %%
# visualize interaction table
im = imshow(K)
clb = colorbar(im)
clb.set_label("Stiffness", fontsize=14)
# Out:
# Figure(PyObject <Figure size 640x480 with 2 Axes>)

# %%
# plot histgram of spring constants
hist(log.(10,K[:]))
title("Distribution of stiffnesses")
xlabel(L"\log \ K", fontsize=14);
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %% [markdown]
# Now we defined our Spring matrix $S$ as
#
# $S_{ij} = A_{ij}  K(s_i, s_j)$

# %%
function seq2Springs(seq, K, A)
    # convert a sequence into a matrix that stores
    # the spring constant between node i and node j.
    S = zeros(size(A))
    for j in 1:size(A,2), i in 1:size(A,1)
        S[i,j] = A[i,j] * K[ seq[i], seq[j]]
    end
    return S
end
# Out:
# seq2Springs (generic function with 1 method)

# %%
# Define parameters
W = 10 # width of network
L = 10 # length of network
q = 5 # number of node types
disorder = 0.1 # spatial disorder added to structure
k_min = 1e-2 # softest spring constant in interaction table
k_max = 1e1 # stiffest spring constant in interaction table

r, A = buildStructure(W, L, disorder)
seq = rand(1:q, W*L)
K = buildSpringTable(q, k_min, k_max)
S = seq2Springs(seq, K, A)

imshow(S)
colorbar(label = "Spring Stiffness")
# Out:
# Figure(PyObject <Figure size 640x480 with 2 Axes>)
# PyObject <matplotlib.colorbar.Colorbar object at 0x1668265c0>

# %%
# test for symmetry
K == K'
# Out:
# true

# %%
imshow(A)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.image.AxesImage object at 0x7f253aecacf8>

# %% [markdown]
# ## Plotting a spring constants on network.

# %%
function plotBondStiffness!(ax,r, A, S;
                            bondWidth=3,
                            nodeSize=30,
                            cmap="Purples",
                            k_min=1e-2,
                            k_max=1e1)
    # Plots network coloring springs by their stiffness
    # uses PyPlot, LinearAlgebra
    cmap = get_cmap(cmap)
    k_min = log(10,k_min)
    k_max = log(10,k_max)
    xy = r2xy(r)
    x = xy[:,1]
    y = xy[:,2]
    N = size(A,1)
    for i =2:N, j in 1:(i-1)
        if A[i,j] != 0
            bondColor = cmap( (log(10,S[i,j]) - k_min) / (k_max - k_min))
            ax.plot([x[i],x[j]], [y[i],y[j]], lw=bondWidth, c=bondColor, zorder=0)
        end
    end
    ax.scatter(x,y, nodeSize, c="black",zorder=2)
    ax.axis("equal")
    ax.axis("off")
    return nothing
end

@show seq
fig, ax = subplots()
plotNetwork!(ax, r, A, bondWidth=5)
plotBondStiffness!(ax, r, A, S, bondWidth=3)
# Out:
# seq = [3, 2, 2, 5, 1, 2, 5, 5, 5, 2, 2, 3, 2, 3, 4, 2, 5, 4, 4, 1, 5, 2, 3, 3, 1, 3, 2, 2, 5, 5, 5, 4, 2, 4, 1, 1, 3, 4, 2, 2, 4, 1, 4, 4, 3, 5, 5, 3, 4, 1, 1, 3, 4, 5, 2, 3, 4, 1, 1, 4, 4, 4, 5, 4, 5, 2, 1, 5, 2, 4, 3, 2, 2, 3, 5, 1, 3, 1, 4, 4, 1, 3, 2, 4, 1, 2, 5, 5, 1, 3, 3, 2, 5, 1, 2, 3, 5, 5, 3, 5]
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %% [markdown]
# A network with a different sequence will have a different pattern of stiffnesses.

# %%
seq = rand(1:q, W*L) 
S = seq2Springs(seq, K, A) 
@show seq
fig, ax = subplots()
plotNetwork!(ax, r, A, bondWidth=5)
plotBondStiffness!(ax, r, A, S, bondWidth=3)
# Out:
# seq = [1, 3, 5, 5, 5, 1, 1, 3, 5, 4, 1, 3, 1, 2, 2, 2, 1, 3, 1, 1, 1, 3, 3, 1, 1, 3, 3, 3, 1, 1, 5, 5, 2, 1, 3, 5, 1, 3, 4, 5, 1, 2, 1, 1, 1, 1, 1, 1, 1, 5, 1, 2, 4, 2, 4, 1, 3, 5, 1, 5, 2, 4, 5, 3, 2, 2, 2, 5, 2, 5, 2, 3, 4, 5, 1, 1, 4, 2, 1, 2, 3, 1, 1, 1, 2, 2, 5, 4, 3, 3, 3, 1, 4, 4, 3, 3, 4, 2, 2, 2]
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %% [markdown]
# Our next task is to define and measure allostery in a network. Then evolve (optimize) the network by mutating the sequence (varying the parameters).
#
# I've add the functions we defined above, `buildSpringTable`, `seq2Springs` and `plotBondStiffness!` in to a module `src/Elastic_N4.jl`
